# %% [markdown]
# <a href="https://colab.research.google.com/github/suyash-i7/Everday_learning/blob/main/L1_Learning_4dec_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###Traditional programme

# %%
import numpy as np

# %%
1st=[1,0,"hi"]
# Out:
#   File "/tmp/ipython-input-825582685.py", line 1
#     1st=[1,0,"hi"]
#     ^
# SyntaxError: invalid decimal literal

# %%
a=[1,3,"hi",4.0]

# %%
x_array=np.array(a)
x_array
# Out:
# array(['1', '3', 'hi', '4.0'], dtype='<U32')

# %%
x_array=a_array.shape(-1,1)
x_array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1530513159.py in <cell line: 0>()
# ----> 1 x_array=a_array.shape(-1,1)
#       2 x_array
#
# NameError: name 'a_array' is not defined

# %%
x_array=a.shape(-1,1)
x_array
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3123726081.py in <cell line: 0>()
# ----> 1 x_array=a.shape(-1,1)
#       2 x_array
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
x_array = x_array.reshape(-1, 1)
x_array
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2981933684.py in <cell line: 0>()
# ----> 1 x_array=x_array.shape(-1,1)
#       2 x_array
#
# TypeError: 'tuple' object is not callable

# %%
b=[3,4,5,6]

# %%
x_array=np.array(b)
x_array
# Out:
# array([3, 4, 5, 6])

# %%
x_array=x_array.shape(1,-1)
x_array
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-286701630.py in <cell line: 0>()
# ----> 1 x_array=x_array.shape(1,-1)
#       2 x_array
#
# TypeError: 'tuple' object is not callable

# %%
from skleran.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1731158464.py in <cell line: 0>()
# ----> 1 from skleran.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'skleran'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
x=[1,2,3,5]
y=[4,8,12,20]

# %%
X_arr=np.array(x)
X_arr,type(X_arr)
# Out:
# (array([1, 2, 3, 5]), numpy.ndarray)

# %%
X_arr.shape
# Out:
# (4,)

# %%
Y_arr=np.array(y)
Y_arr
# Out:
# array([ 4,  8, 12, 20])

# %%
X_arr=X_arr.shape(-1,1)
X_arr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2069376014.py in <cell line: 0>()
# ----> 1 X_arr=X_arr.shape(-1,1)
#       2 X_arr
#
# TypeError: 'tuple' object is not callable

# %%
y_arr=np.array([50,100,-50])
y_arr
# Out:
# array([ 50, 100, -50])

# %%
x_arr=np.array([25,50,-50])
x_arr
# Out:
# array([ 25,  50, -50])

# %%
X_arr_reshaped = X_arr.reshape(-1, 1)
model.fit(X_arr_reshaped, Y_arr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-791216779.py in <cell line: 0>()
# ----> 1 model.LinearRegression()
#
# AttributeError: 'LinearRegression' object has no attribute 'LinearRegression'
